# %% [markdown]
# # **DRIVE ACCESS AUTHENTICATION**

# %%
# !wget https://raw.githubusercontent.com/ktan1008/ML-Task-1/main/oasis_longitudinal.csv
# Out:
# --2021-10-09 16:44:24--  https://raw.githubusercontent.com/ktan1008/ML-Task-1/main/oasis_longitudinal.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27916 (27K) [text/plain]
# Saving to: ‘oasis_longitudinal.csv.3’
#
# oasis_longitudinal. 100%[===================>]  27.26K  --.-KB/s    in 0.001s
#
# 2021-10-09 16:44:24 (23.3 MB/s) - ‘oasis_longitudinal.csv.3’ saved [27916/27916]

# %% [markdown]
# # **IMPORTING PACKAGES**

# %%
import pandas as pd               # dataframe operations 
import numpy as np# numeric operations

# %% [markdown]
# # **READING THE DATASET**

# %%
path = '/content/oasis_longitudinal.csv'  # path of the dataset 

df = pd.read_csv(path)  # reads data and stores as dataframe

# %% [markdown]
# # **DATA PREPROCESSING**

# %% [markdown]
# **SOME PANDAS COMMANDS**

# %%
df
# Out:
#     Subject ID         MRI ID        Group  Visit  ...  CDR  eTIV   nWBV    ASF
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1  ...  0.0  1987  0.696  0.883
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2  ...  0.0  2004  0.681  0.876
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1  ...  0.5  1678  0.736  1.046
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2  ...  0.5  1738  0.713  1.010
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3  ...  0.5  1698  0.701  1.034
# ..         ...            ...          ...    ...  ...  ...   ...    ...    ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2  ...  0.5  1693  0.694  1.037
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3  ...  0.5  1688  0.675  1.040
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1  ...  0.0  1319  0.801  1.331
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2  ...  0.0  1327  0.796  1.323
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3  ...  0.0  1333  0.801  1.317
#
# [373 rows x 15 columns]

# %%
# shows n entries from the beginning of the dataset 
#  default = 5 
df.head(4)
# Out:
#   Subject ID         MRI ID        Group  Visit  ...  CDR  eTIV   nWBV    ASF
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1  ...  0.0  1987  0.696  0.883
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2  ...  0.0  2004  0.681  0.876
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1  ...  0.5  1678  0.736  1.046
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2  ...  0.5  1738  0.713  1.010
#
# [4 rows x 15 columns]

# %%
# shows n entries from the end of the dataset 
#  default = 5 
df.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  ...  CDR  eTIV   nWBV    ASF
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2  ...  0.5  1693  0.694  1.037
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3  ...  0.5  1688  0.675  1.040
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1  ...  0.0  1319  0.801  1.331
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2  ...  0.0  1327  0.796  1.323
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3  ...  0.0  1333  0.801  1.317
#
# [5 rows x 15 columns]

# %%
# returns the size of the dataframe
df.shape
# Out:
# (373, 15)

# %%
# outputs the name of the columns 
df.columns
# Out:
# Index(['Subject ID', 'MRI ID', 'Group', 'Visit', 'MR Delay', 'M/F', 'Hand',
#        'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF'],
#       dtype='object')

# %%
# returns the data type and the number of entries of all columns 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         354 non-null    float64
#  10  MMSE        371 non-null    float64
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
# returns the unique values of a column 
df['M/F'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# shows the count of unique value in a column
df['M/F'].value_counts(dropna = False)
# Out:
# F    213
# M    160
# Name: M/F, dtype: int64

# %%
df['SES'].value_counts(dropna = True)
# Out:
# 2.0    103
# 1.0     88
# 3.0     82
# 4.0     74
# 5.0      7
# Name: SES, dtype: int64

# %%
# renames the columns
# inplace makes changes to the original dataset 
# in case inplace = False , a temporary dataframe instance is created
df.rename(columns = {'M/F' : 'Gender'} , inplace = True)

# %%
# renamed column 
df
# Out:
#     Subject ID         MRI ID        Group  Visit  ...  CDR  eTIV   nWBV    ASF
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1  ...  0.0  1987  0.696  0.883
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2  ...  0.0  2004  0.681  0.876
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1  ...  0.5  1678  0.736  1.046
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2  ...  0.5  1738  0.713  1.010
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3  ...  0.5  1698  0.701  1.034
# ..         ...            ...          ...    ...  ...  ...   ...    ...    ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2  ...  0.5  1693  0.694  1.037
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3  ...  0.5  1688  0.675  1.040
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1  ...  0.0  1319  0.801  1.331
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2  ...  0.0  1327  0.796  1.323
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3  ...  0.0  1333  0.801  1.317
#
# [373 rows x 15 columns]

# %%
# the columns which provide no info of relevance are dropped from the dataframe 
# axis - 0 : rows , 
df.drop(labels = {'Subject ID' , 'MRI ID' ,'Visit' , 'MR Delay' } , axis = 1 , inplace = True)

# %%
df
# Out:
#            Group Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Nondemented      M    R   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    Nondemented      M    R   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2       Demented      M    R   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3       Demented      M    R   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4       Demented      M    R   80    12  NaN  22.0  0.5  1698  0.701  1.034
# ..           ...    ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368     Demented      M    R   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369     Demented      M    R   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370  Nondemented      F    R   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371  Nondemented      F    R   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372  Nondemented      F    R   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 11 columns]

# %%
df.describe()
# Out:
#               Age        EDUC         SES  ...         eTIV        nWBV         ASF
# count  373.000000  373.000000  354.000000  ...   373.000000  373.000000  373.000000
# mean    77.013405   14.597855    2.460452  ...  1488.128686    0.729568    1.195461
# std      7.640957    2.876339    1.134005  ...   176.139286    0.037135    0.138092
# min     60.000000    6.000000    1.000000  ...  1106.000000    0.644000    0.876000
# 25%     71.000000   12.000000    2.000000  ...  1357.000000    0.700000    1.099000
# 50%     77.000000   15.000000    2.000000  ...  1470.000000    0.729000    1.194000
# 75%     82.000000   16.000000    3.000000  ...  1597.000000    0.756000    1.293000
# max     98.000000   23.000000    5.000000  ...  2004.000000    0.837000    1.587000
#
# [8 rows x 8 columns]

# %% [markdown]
# **REMOVING / REPLACING NULL VALUES**

# %%
# is null returns true for null values and false for null values 
# the sum() gives the total count of null values for each row 

df.isnull().sum()
# Out:
# Group      0
# Gender     0
# Hand       0
# Age        0
# EDUC       0
# SES       19
# MMSE       2
# CDR        0
# eTIV       0
# nWBV       0
# ASF        0
# dtype: int64

# %%
# count() returns the count of non null values of the column 
df['SES'].count()
# Out:
# 354

# %%
# drops all the rows containing null values from the dataframe 
null_rem = df.dropna()

# %%
# comparision 
print( "Original Dataframe : \n",df.head() ,"\n\n" , "New Dataframe : \n" ,null_rem.head())
# Out:
# Original Dataframe :
#           Group Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  Nondemented      M    R   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1  Nondemented      M    R   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2     Demented      M    R   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3     Demented      M    R   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4     Demented      M    R   80    12  NaN  22.0  0.5  1698  0.701  1.034
#
#  New Dataframe :
#           Group Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  Nondemented      M    R   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1  Nondemented      M    R   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 5  Nondemented      F    R   88    18  3.0  28.0  0.0  1215  0.710  1.444
# 6  Nondemented      F    R   90    18  3.0  27.0  0.0  1200  0.718  1.462
# 7  Nondemented      M    R   80    12  4.0  28.0  0.0  1689  0.712  1.039

# %%
# dropping all null values from a column 
null_rem_col = df.dropna(subset = ['MMSE'])

# %%
null_rem_col['MMSE'].isnull().sum()
# Out:
# 0

# %%
null_rem_col.shape
# Out:
# (371, 11)

# %%
# replacing null values
# replace them by either mean or median 
# we will replace them with median

# columns which have null values
col_null = ['MMSE' , 'SES'] 
med = []

# loop for obtaining the median 
for i in col_null: 
  med.append(df[i].median())  

print("Median Values : " , med[0] , med[1])

k = 0 

# loop for replacing null values 
for i in col_null:
  df[i].fillna(med[k] , inplace = True)    # fillna fills the null values 
  k = k + 1
# Out:
# Median Values :  29.0 2.0

# %%
# checking for null values again 

df.isnull().sum()
# Out:
# Group     0
# Gender    0
# Hand      0
# Age       0
# EDUC      0
# SES       0
# MMSE      0
# CDR       0
# eTIV      0
# nWBV      0
# ASF       0
# dtype: int64

# %%
dv = df.copy()

# %%
dv
# Out:
#            Group Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Nondemented      M    R   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    Nondemented      M    R   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2       Demented      M    R   75    12  2.0  23.0  0.5  1678  0.736  1.046
# 3       Demented      M    R   76    12  2.0  28.0  0.5  1738  0.713  1.010
# 4       Demented      M    R   80    12  2.0  22.0  0.5  1698  0.701  1.034
# ..           ...    ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368     Demented      M    R   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369     Demented      M    R   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370  Nondemented      F    R   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371  Nondemented      F    R   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372  Nondemented      F    R   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 11 columns]

# %% [markdown]
# # Task

# %% [markdown]
# The tasks are as follows :
# 1. Copy df into another dataframe using copy(). Make 2 such copies : df_copy , vis_copy
# 2. Implement Sklearn label encoding on df
# 3. Implement dummy encoding on the df_copy
# 4. Plot a simple barplot depicting the count / number of males and females using vis_copy

# %% [markdown]
# ### 1.Copy df into another dataframe using copy(). Make 2 such copies : df_copy , vis_copy

# %%
df_copy=df.copy()
vis_copy=df.copy()

# %% [markdown]
# ## 2. Implement Sklearn label encoding on df

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.columns
# Out:
# Index(['Group', 'Gender', 'Hand', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV',
#        'nWBV', 'ASF'],
#       dtype='object')

# %%
categ=['Group', 'Gender', 'Hand', 'Age', 'EDUC', 'SES', 'MMSE', 'CDR', 'eTIV',
       'nWBV', 'ASF']

# %%
le=LabelEncoder()
df[categ] = df[categ].apply(le.fit_transform)

# %%
df
# Out:
#      Group  Gender  Hand  Age  EDUC  SES  MMSE  CDR  eTIV  nWBV  ASF
# 0        2       1     0   27     5    1    14    0   284    35    1
# 1        2       1     0   28     5    1    17    0   285    20    0
# 2        1       1     0   15     3    1    10    1   231    73   52
# 3        1       1     0   16     3    1    15    1   254    51   32
# 4        1       1     0   20     3    1     9    1   238    40   46
# ..     ...     ...   ...  ...   ...  ...   ...  ...   ...   ...  ...
# 368      1       1     0   22     7    0    15    1   236    33   48
# 369      1       1     0   26     7    0    13    1   233    14   50
# 370      2       0     0    1     4    1    17    0    51   126  215
# 371      2       0     0    3     4    1    17    0    56   124  211
# 372      2       0     0    5     4    1    17    0    60   126  208
#
# [373 rows x 11 columns]

# %% [markdown]
# ### 3. Implement dummy encoding on the df_copy

# %%
dummies=pd.get_dummies(df_copy)
dummies
# Out:
#      Age  EDUC  SES  MMSE  ...  Group_Nondemented  Gender_F  Gender_M  Hand_R
# 0     87    14  2.0  27.0  ...                  1         0         1       1
# 1     88    14  2.0  30.0  ...                  1         0         1       1
# 2     75    12  2.0  23.0  ...                  0         0         1       1
# 3     76    12  2.0  28.0  ...                  0         0         1       1
# 4     80    12  2.0  22.0  ...                  0         0         1       1
# ..   ...   ...  ...   ...  ...                ...       ...       ...     ...
# 368   82    16  1.0  28.0  ...                  0         0         1       1
# 369   86    16  1.0  26.0  ...                  0         0         1       1
# 370   61    13  2.0  30.0  ...                  1         1         0       1
# 371   63    13  2.0  30.0  ...                  1         1         0       1
# 372   65    13  2.0  30.0  ...                  1         1         0       1
#
# [373 rows x 14 columns]

# %%
vis_copy
# Out:
#            Group Gender Hand  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Nondemented      M    R   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    Nondemented      M    R   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2       Demented      M    R   75    12  2.0  23.0  0.5  1678  0.736  1.046
# 3       Demented      M    R   76    12  2.0  28.0  0.5  1738  0.713  1.010
# 4       Demented      M    R   80    12  2.0  22.0  0.5  1698  0.701  1.034
# ..           ...    ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368     Demented      M    R   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369     Demented      M    R   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370  Nondemented      F    R   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371  Nondemented      F    R   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372  Nondemented      F    R   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

vis_copy['Gender'].value_counts().plot(kind='bar');
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Count of Males and Females")
# Out:
# Text(0.5, 1.0, 'Count of Males and Females')

# %%
# this is how the plot should look like
